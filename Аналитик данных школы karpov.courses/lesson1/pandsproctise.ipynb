# %%
import pandas as pd

# %%
# !ls
# Out:
# 'Deep Learning базовый поток'   setup.py
#  main.py		        titanic.csv
#  pandsproctise.ipynb	        venv
#  readme.md		       'Аналитик данных школы karpov.courses'

# %%
taxi = pd.read_csv('https://stepik.org/media/attachments/lesson/360340/2_taxi_nyc.csv')

# %%
taxi.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pickup_dt     29101 non-null  object
#  1   pickup_month  29101 non-null  object
#  2   borough       26058 non-null  object
#  3   pickups       29101 non-null  int64
#  4   hday          29101 non-null  object
#  5   spd           29101 non-null  float64
#  6   vsb           29101 non-null  float64
#  7   temp          29101 non-null  float64
#  8   dewp          29101 non-null  float64
#  9   slp           29101 non-null  float64
#  10  pcp 01        29101 non-null  float64
#  11  pcp 06        29101 non-null  float64
#  12  pcp 24        29101 non-null  float64
#  13  sd            29101 non-null  float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
taxi.describe()
# Out:
#             pickups           spd           vsb          temp          dewp  \
# count  29101.000000  29101.000000  29101.000000  29101.000000  29101.000000
# mean     490.215903      5.984924      8.818125     47.669042     30.823065
# std      995.649536      3.699007      2.442897     19.814969     21.283444
# min        0.000000      0.000000      0.000000      2.000000    -16.000000
# 25%        1.000000      3.000000      9.100000     32.000000     14.000000
# 50%       54.000000      6.000000     10.000000     46.000000     30.000000
# 75%      449.000000      8.000000     10.000000     64.500000     50.000000
# max     7883.000000     21.000000     10.000000     89.000000     73.000000
#
#                 slp        pcp 01        pcp 06        pcp 24            sd
# count  29101.000000  29101.000000  29101.000000  29101.000000  29101.000000
# mean    1017.817938      0.003830      0.026129      0.090464      2.529169
# ...

# %%
taxi.rename(columns={'pcp 01': 'pcp_01', 'pcp 06': 'pcp_06', 'pcp 24': 'pcp_24'})
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
taxi
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp 01  pcp 06  pcp 24   sd
# ...

# %%
taxi.query("borough == 'Manhattan'").shape
# Out:
# (4343, 14)

# %%
taxi[taxi['borough'] == 'Brooklyn'].shape
# Out:
# (4343, 14)

# %%
taxi[taxi['borough'] == 'Brooklyn'].shape
# Out:
# (4343, 14)

# %%
taxi.query("borough == 'Brooklyn'").head()
# Out:
#               pickup_dt pickup_month   borough  pickups hday  spd   vsb  temp  \
# 1   2015-01-01 01:00:00          Jan  Brooklyn     1519    Y  5.0  10.0  30.0
# 8   2015-01-01 02:00:00          Jan  Brooklyn     1229    Y  3.0  10.0  30.0
# 15  2015-01-01 03:00:00          Jan  Brooklyn     1601    Y  5.0  10.0  30.0
# 22  2015-01-01 04:00:00          Jan  Brooklyn     1390    Y  5.0  10.0  29.0
# 29  2015-01-01 05:00:00          Jan  Brooklyn      759    Y  5.0  10.0  28.0
#
#     dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 1    7.0  1023.5     0.0     0.0     0.0  0.0
# 8    6.0  1023.0     0.0     0.0     0.0  0.0
# 15   8.0  1022.3     0.0     0.0     0.0  0.0
# 22   9.0  1022.0     0.0     0.0     0.0  0.0
# 29   9.0  1021.8     0.0     0.0     0.0  0.0

# %%
taxi.pickups.sum()
# Out:
# 14265773

# %%
taxi[taxi.pickups == taxi.pickups.max()]
# Out:
#                  pickup_dt pickup_month    borough  pickups hday  spd  vsb  \
# 28604  2015-06-27 22:00:00          Jun  Manhattan     7883    N  8.0  5.5
#
#        temp  dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 28604  60.0  56.5  1016.9   0.065     0.0     0.0  0.0

# %%
taxi.pickups.idxmax()
# Out:
# 28604

# %%
taxi.pickups.max()
# Out:
# 7883

# %%
taxi.pickups.idxmin()
# Out:
# 2

# %%
taxi.loc[taxi.pickups.idxmin()]['borough']
# Out:
# 'EWR'

# %%
mean_picks = taxi.groupby(['borough', 'hday']).aggregate({'pickups': 'mean'})

# %%
mean_picks
# Out:
#                         pickups
# borough       hday
# Bronx         N       50.771073
#               Y       48.065868
# Brooklyn      N      534.727969
#               Y      527.011976
# EWR           N        0.023467
#               Y        0.041916
# Manhattan     N     2401.302921
#               Y     2035.928144
# Queens        N      308.899904
#               Y      320.730539
# Staten Island N        1.606082
#               Y        1.497006

# %%
mean_picks = taxi.groupby(['borough', 'hday'], as_index=False).aggregate({'pickups': 'mean'})

# %%
 taxi.groupby(['borough', 'hday']).aggregate({'pickups': 'mean'})\
    .groupby(['borough']).aggregate({'pickups': 'min'})
# Out:
#                    pickups
# borough
# Bronx            48.065868
# Brooklyn        527.011976
# EWR               0.023467
# Manhattan      2035.928144
# Queens          308.899904
# Staten Island     1.497006

# %%
 taxi.groupby(['borough', 'pickup_month'], as_index=False).aggregate({'pickups': 'sum'})\
    .sort_values(by='pickups', ascending=False)
# Out:
#           borough pickup_month  pickups
# 21      Manhattan          Jun  1995388
# 23      Manhattan          May  1888800
# 19      Manhattan          Feb  1718571
# 22      Manhattan          Mar  1661261
# 18      Manhattan          Apr  1648278
# 20      Manhattan          Jan  1455543
# 9        Brooklyn          Jun   482466
# 11       Brooklyn          May   476087
# 6        Brooklyn          Apr   378095
# 10       Brooklyn          Mar   346726
# 7        Brooklyn          Feb   328650
# 8        Brooklyn          Jan   309011
# 27         Queens          Jun   286311
# 29         Queens          May   275893
# 28         Queens          Mar   219561
# 24         Queens          Apr   216857
# 25         Queens          Feb   185695
# 26         Queens          Jan   159211
# 5           Bronx          May    53037
# 3           Bronx          Jun    49006
# 0           Bronx          Apr    34617
# 4           Bronx          Mar    32232
# ...

# %%
taxi.columns
# Out:
# Index(['pickup_dt', 'pickup_month', 'borough', 'pickups', 'hday', 'spd', 'vsb',
#        'temp', 'dewp', 'slp', 'pcp 01', 'pcp 06', 'pcp 24', 'sd'],
#       dtype='object')

# %%
temp = taxi.temp

# %%
temp.head()
# Out:
# 0    30.0
# 1    30.0
# 2    30.0
# 3    30.0
# 4    30.0
# Name: temp, dtype: float64

# %%
temp = (temp - 32) * 5 / 9

# %%
temp
# Out:
# 0        -1.111111
# 1        -1.111111
# 2        -1.111111
# 3        -1.111111
# 4        -1.111111
#            ...
# 29096    23.888889
# 29097    23.888889
# 29098    23.888889
# 29099    23.888889
# 29100    23.888889
# Name: temp, Length: 29101, dtype: float64
